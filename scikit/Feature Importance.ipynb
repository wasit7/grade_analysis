# %%
pwd
# Out:
# u'C:\\Users\\Wasit\\Documents\\GitHub\\grade_analysis\\scikit'

# %%
import pandas as pd
import numpy as np
df_csv= pd.read_pickle("../df_noplus/df5.pkl")
all_subjects=df_csv['COURSEID'].value_counts()
##removing any subject enrolled less than 20 times
#all_subjects=all_subjects[all_subjects>=20]
print df_csv.shape
df_csv=df_csv[df_csv["COURSEID"].isin(all_subjects.index)]
print df_csv.shape
# Out:
# (28272, 199)
# (28272, 199)
# C:\Anaconda\lib\site-packages\pandas\computation\__init__.py:19: UserWarning: The installed version of numexpr 2.4.4 is not supported in pandas and will be not be used
#
#   UserWarning)

# %%
for subject,count in all_subjects.iteritems():
    print subject
    ##load data
    dfx=df_csv[df_csv['COURSEID']==subject]
    dfx=dfx.iloc[np.random.permutation(len(dfx))]
    ##convert to np.array
    X=dfx.as_matrix( dfx.columns[4:] )
    y=dfx.as_matrix( ['GRADE'] ).T[0]
    ##evaluation
# Out:
# MA211
# CS102
# CS101
# TU154
# TH161
# CS111
# CS213
# EL171
# SC135
# PY228
# EL172
# SC185
# TU110
# CS223
# TU120
# ST216
# CS284
# EL295
# TU130
# MA212
# MA332
# CS314
# CS222
# CS214
# CS261
# CS251
# CS281
# CS341
# EL395
# CS301
# CS311
# CS374
# CS302
# CS401
# CS342
# CS105
# HO201
# CS395
# CS402
# CS365
# EL070
# AT326
# TU100
# CS289
# CS385
# AT316
# CS326
# TU122
# CS288
# CS487
# CS211
# CS489
# SC123
# SC173
# CS296
# CS488
# SW111
# CS367
# SW365
# CS486
# SW212
# CS409
# SW221
# CS215
# CS386
# CS366
# CS295
# CS377
# LA209
# CS456
# CS467
# CS300
# SW478
# SW213
# MW314
# BA291
# SW475
# CS396
# CS427
# ES356
# CS387
# CS286
# CS297
# CS429
# CS446
# SW335
# CS356
# HR201
# CS459
# SO201
# NS132
# TA395
# CJ321
# CS397
# CS398
# CS348
# CJ317
# MW313
# CJ316
# MA216
# CS407
# CS115
# CS457
# CS388
# CS426
# CS449
# CS408
# CJ315
# CS285
# CS399
# PY218
# CS328
# AT366
# CS359
# JC201
# TU153
# ES456
# CS469
# CS479
# EC210
# CS499
# PY211
# PE245
# CS447
# ES256
# AS171
# TU116
# PM235
# CS496
# PM236
# EG241
# AT207
# SW366
# MU100
# PY237
# JC200
# IS201
# TU115
# JP171
# PY226
# PY267
# MA217
# MU130
# JC260
# FN211
# MU135
# TD436
# PM215
# MU278
# MU202
# RT326
# MA221
# PE240
# DM201
# CS275
# CF367
# CF366
# HS266
# HS269
# SW224
# PY217
# GE311
# SW223
# MW318
# GE225
# HS356
# AS178
# SW489
# SN212
# JP172
# SW222
# MU275
# AT346
# MU277
# ST218
# CS231
# RE333
# TU156
# AN201
# JC281
# SW467
# TU111
# AS177
# DM215
# PC286
# FD211
# EL202
# AT336
# NS112
# DM207
# CN342
# SW486
# SW214
# EL231
# HS360

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier

subject='CS213'
print subject

def get_importances20(subject,pattern_names):
    ##load data
    dfx=df_csv[df_csv['COURSEID']==subject]
    dfx=dfx.iloc[np.random.permutation(len(dfx))]
    ##convert to np.array
    X=dfx.as_matrix( dfx.columns[4:] )
    y=dfx.as_matrix( ['GRADE'] ).T[0]

    # Build a forest and compute the feature importances
    forest = ExtraTreesClassifier(n_estimators=250,
                                  random_state=0)

    forest.fit(X, y)
    importances = forest.feature_importances_
    #std = np.std([tree.feature_importances_ for tree in forest.estimators_],
    #             axis=0)
    indices = np.argsort(importances)[::-1]
    obj=pattern_names[indices[(importances[indices].cumsum()<0.2)  & (importances[indices] > 0.05) ]]
    import_list = [i for i in obj][:3]
    return (import_list, indices, importances)

# Print the feature ranking
print("Feature ranking:")

pattern_names=df_csv.columns[4:]
import_list, indices, importances = get_importances20(subject,pattern_names)
print import_list

for f in range(X.shape[1]):
    print("%d. subject %s (%f)" % (f + 1, pattern_names[indices[f]], importances[indices[f]]))
# Out:
# CS213
# Feature ranking:
# ['CS111', 'CS102', 'MA211']
# 1. subject CS111 (0.076519)
# 2. subject CS102 (0.056108)
# 3. subject MA211 (0.053830)
# 4. subject TU154 (0.049508)
# 5. subject EL172 (0.042700)
# 6. subject EL171 (0.042301)
# 7. subject TU120 (0.041546)
# 8. subject SC135 (0.041322)
# 9. subject CS101 (0.040399)
# 10. subject TH161 (0.036136)
# 11. subject TU110 (0.036019)
# 12. subject PY228 (0.035062)
# 13. subject SC185 (0.030746)
# 14. subject CS105 (0.029115)
# 15. subject TU100 (0.023721)
# 16. subject EL070 (0.021139)
# 17. subject TU130 (0.020224)
# 18. subject MA212 (0.017736)
# 19. subject ST216 (0.017673)
# 20. subject SW111 (0.012403)
# 21. subject LA209 (0.011624)
# 22. subject SW335 (0.010993)
# 23. subject TU122 (0.010596)
# 24. subject CS115 (0.009238)
# 25. subject SC123 (0.008300)
# 26. subject MW313 (0.008118)
# 27. subject MW314 (0.007759)
# 28. subject SC173 (0.007688)
# 29. subject SW213 (0.007512)
# 30. subject SO201 (0.007387)
# 31. subject SW212 (0.007346)
# 32. subject AT316 (0.006840)
# 33. subject CS214 (0.006567)
# 34. subject EL295 (0.006016)
# 35. subject CS222 (0.005808)
# 36. subject CS314 (0.005494)
# 37. subject CS261 (0.005462)
# 38. subject MA332 (0.005428)
# 39. subject SW221 (0.005211)
# 40. subject CS213 (0.005206)
# 41. subject HO201 (0.005177)
# 42. subject EL395 (0.004946)
# 43. subject SW475 (0.004549)
# 44. subject CS251 (0.004543)
# 45. subject ES356 (0.004445)
# 46. subject CJ316 (0.004435)
# 47. subject CS223 (0.004358)
# 48. subject CS341 (0.004353)
# 49. subject CS284 (0.004336)
# 50. subject CS281 (0.004095)
# 51. subject CS365 (0.003979)
# 52. subject SW365 (0.003802)
# 53. subject CJ317 (0.003521)
# 54. subject AT326 (0.003510)
# 55. subject TA395 (0.003504)
# 56. subject MA216 (0.003317)
# 57. subject CJ315 (0.002950)
# 58. subject CS395 (0.002926)
# 59. subject CS289 (0.002847)
# 60. subject TU153 (0.002699)
# 61. subject CS385 (0.002665)
# 62. subject NS132 (0.002340)
# 63. subject PE245 (0.002244)
# 64. subject CS301 (0.002196)
# 65. subject CS311 (0.001858)
# 66. subject CS374 (0.001642)
# 67. subject SW478 (0.001560)
# 68. subject CS342 (0.001530)
# 69. subject CS296 (0.001387)
# 70. subject CS288 (0.001313)
# 71. subject PM236 (0.001297)
# 72. subject AS171 (0.001207)
# 73. subject CS409 (0.001101)
# 74. subject MA217 (0.001033)
# 75. subject JC200 (0.001030)
# 76. subject CS302 (0.001024)
# 77. subject CS489 (0.000984)
# 78. subject PY267 (0.000960)
# 79. subject CS401 (0.000948)
# 80. subject PM235 (0.000937)
# 81. subject ES456 (0.000920)
# 82. subject PY218 (0.000881)
# 83. subject CS487 (0.000875)
# 84. subject CS402 (0.000867)
# 85. subject CS295 (0.000864)
# 86. subject TU116 (0.000825)
# 87. subject AT336 (0.000806)
# 88. subject CS367 (0.000684)
# 89. subject CS486 (0.000641)
# 90. subject PM215 (0.000623)
# 91. subject MU277 (0.000599)
# 92. subject CS488 (0.000597)
# 93. subject JC260 (0.000580)
# 94. subject CS386 (0.000562)
# 95. subject AT366 (0.000546)
# 96. subject CS366 (0.000541)
# 97. subject HS360 (0.000485)
# 98. subject CS286 (0.000477)
# 99. subject HS266 (0.000462)
# 100. subject NS112 (0.000437)
# 101. subject JC201 (0.000432)
# 102. subject CS326 (0.000429)
# 103. subject MU135 (0.000404)
# 104. subject CS396 (0.000379)
# 105. subject CS297 (0.000367)
# 106. subject CS408 (0.000351)
# 107. subject GE225 (0.000351)
# 108. subject BA291 (0.000338)
# 109. subject MU202 (0.000336)
# 110. subject CS429 (0.000328)
# 111. subject MU275 (0.000327)
# 112. subject TU115 (0.000298)
# 113. subject CS427 (0.000233)
# 114. subject EC210 (0.000226)
# 115. subject SW366 (0.000209)
# 116. subject DM201 (0.000205)
# 117. subject AT207 (0.000204)
# 118. subject CS398 (0.000179)
# 119. subject CS426 (0.000161)
# 120. subject CS467 (0.000146)
# 121. subject CS397 (0.000144)
# 122. subject FN211 (0.000136)
# 123. subject CS348 (0.000128)
# 124. subject MW318 (0.000034)
# 125. subject SW467 (0.000023)
# 126. subject CF366 (0.000014)
# 127. subject CS356 (0.000000)
# 128. subject CN342 (0.000000)
# 129. subject CS328 (0.000000)
# 130. subject AS177 (0.000000)
# 131. subject CS300 (0.000000)
# 132. subject CS285 (0.000000)
# 133. subject CS275 (0.000000)
# 134. subject AT346 (0.000000)
# 135. subject CS231 (0.000000)
# 136. subject CS215 (0.000000)
# 137. subject CS211 (0.000000)
# 138. subject CF367 (0.000000)
# 139. subject CS359 (0.000000)
# 140. subject CJ321 (0.000000)
# 141. subject AS178 (0.000000)
# 142. subject TU156 (0.000000)
# 143. subject CS377 (0.000000)
# 144. subject JC281 (0.000000)
# 145. subject JP172 (0.000000)
# 146. subject MA221 (0.000000)
# 147. subject MU100 (0.000000)
# 148. subject MU130 (0.000000)
# 149. subject MU278 (0.000000)
# 150. subject PC286 (0.000000)
# 151. subject PE240 (0.000000)
# 152. subject PY211 (0.000000)
# 153. subject PY217 (0.000000)
# 154. subject PY226 (0.000000)
# 155. subject PY237 (0.000000)
# 156. subject RE333 (0.000000)
# 157. subject RT326 (0.000000)
# 158. subject SN212 (0.000000)
# 159. subject ST218 (0.000000)
# 160. subject SW214 (0.000000)
# 161. subject SW222 (0.000000)
# 162. subject SW223 (0.000000)
# 163. subject SW224 (0.000000)
# 164. subject SW486 (0.000000)
# 165. subject SW489 (0.000000)
# 166. subject TD436 (0.000000)
# 167. subject TU111 (0.000000)
# 168. subject JP171 (0.000000)
# 169. subject IS201 (0.000000)
# 170. subject CS387 (0.000000)
# 171. subject HS356 (0.000000)
# 172. subject CS388 (0.000000)
# 173. subject CS399 (0.000000)
# 174. subject CS407 (0.000000)
# 175. subject CS446 (0.000000)
# 176. subject CS447 (0.000000)
# 177. subject CS449 (0.000000)
# 178. subject CS456 (0.000000)
# 179. subject CS457 (0.000000)
# 180. subject CS459 (0.000000)
# 181. subject CS469 (0.000000)
# 182. subject CS479 (0.000000)
# 183. subject CS496 (0.000000)
# 184. subject CS499 (0.000000)
# 185. subject DM207 (0.000000)
# 186. subject DM215 (0.000000)
# 187. subject EG241 (0.000000)
# 188. subject EL202 (0.000000)
# 189. subject EL231 (0.000000)
# 190. subject ES256 (0.000000)
# 191. subject FD211 (0.000000)
# 192. subject GE311 (0.000000)
# 193. subject HR201 (0.000000)
# 194. subject HS269 (0.000000)
# 195. subject AN201 (0.000000)

# %%
##generate importance
pattern_names=df_csv.columns[4:]
data3=[{'name':s, 'imports':get_importances20(s,pattern_names)[0]} for s in all_subjects.index]
data3
# Out:
# [{'imports': ['TU154', 'SC135'], 'name': 'MA211'},
#  {'imports': [], 'name': 'CS102'},
#  {'imports': [], 'name': 'CS101'},
#  {'imports': [], 'name': 'TU154'},
#  {'imports': ['CS101'], 'name': 'TH161'},
#  {'imports': ['CS102'], 'name': 'CS111'},
#  {'imports': ['CS111', 'CS102', 'MA211'], 'name': 'CS213'},
#  {'imports': ['TU154'], 'name': 'EL171'},
#  {'imports': ['TU154'], 'name': 'SC135'},
#  {'imports': ['TU154'], 'name': 'PY228'},
#  {'imports': ['EL171'], 'name': 'EL172'},
#  {'imports': ['TU154'], 'name': 'SC185'},
#  {'imports': ['TU154', 'SC135'], 'name': 'TU110'},
#  {'imports': ['CS111', 'MA211', 'TU154'], 'name': 'CS223'},
#  {'imports': ['TU154'], 'name': 'TU120'},
#  {'imports': [], 'name': 'ST216'},
#  {'imports': ['SC135', 'MA211', 'CS111'], 'name': 'CS284'},
#  {'imports': ['EL171', 'EL172', 'MA211'], 'name': 'EL295'},
#  {'imports': ['TU154'], 'name': 'TU130'},
#  {'imports': ['MA211', 'TU154', 'EL171'], 'name': 'MA212'},
#  {'imports': [], 'name': 'MA332'},
#  {'imports': [], 'name': 'CS314'},
#  {'imports': ['CS111', 'TU154', 'MA211'], 'name': 'CS222'},
#  {'imports': ['MA211', 'EL171', 'SC135'], 'name': 'CS214'},
#  {'imports': [], 'name': 'CS261'},
#  {'imports': ['CS223'], 'name': 'CS251'},
#  {'imports': ['CS284'], 'name': 'CS281'},
#  {'imports': [], 'name': 'CS341'},
#  {'imports': [], 'name': 'EL395'},
#  {'imports': [], 'name': 'CS301'},
#  {'imports': [], 'name': 'CS311'},
#  {'imports': [], 'name': 'CS374'},
#  {'imports': [], 'name': 'CS302'},
#  {'imports': [], 'name': 'CS401'},
#  {'imports': [], 'name': 'CS342'},
#  {'imports': [], 'name': 'CS105'},
#  {'imports': [], 'name': 'HO201'},
#  {'imports': [], 'name': 'CS395'},
#  {'imports': [], 'name': 'CS402'},
#  {'imports': [], 'name': 'CS365'},
#  {'imports': ['PY228'], 'name': 'EL070'},
#  {'imports': ['MA211', 'EL171', 'EL172'], 'name': 'AT326'},
#  {'imports': ['TU154'], 'name': 'TU100'},
#  {'imports': [], 'name': 'CS289'},
#  {'imports': [], 'name': 'CS385'},
#  {'imports': ['TU154', 'SC135'], 'name': 'AT316'},
#  {'imports': [], 'name': 'CS326'},
#  {'imports': ['SC135', 'EL171'], 'name': 'TU122'},
#  {'imports': [], 'name': 'CS288'},
#  {'imports': [], 'name': 'CS487'},
#  {'imports': ['CS111', 'MA211', 'TU154'], 'name': 'CS211'},
#  {'imports': [], 'name': 'CS489'},
#  {'imports': ['CS102'], 'name': 'SC123'},
#  {'imports': ['CS102'], 'name': 'SC173'},
#  {'imports': [], 'name': 'CS296'},
#  {'imports': ['CS486'], 'name': 'CS488'},
#  {'imports': ['EL171', 'CS102', 'TU154'], 'name': 'SW111'},
#  {'imports': [], 'name': 'CS367'},
#  {'imports': [], 'name': 'SW365'},
#  {'imports': [], 'name': 'CS486'},
#  {'imports': ['EL171', 'CS102'], 'name': 'SW212'},
#  {'imports': [], 'name': 'CS409'},
#  {'imports': ['CS102'], 'name': 'SW221'},
#  {'imports': ['CS102', 'CS111', 'TU154'], 'name': 'CS215'},
#  {'imports': [], 'name': 'CS386'},
#  {'imports': [], 'name': 'CS366'},
#  {'imports': [], 'name': 'CS295'},
#  {'imports': [], 'name': 'CS377'},
#  {'imports': ['SC135', 'MA211'], 'name': 'LA209'},
#  {'imports': [], 'name': 'CS456'},
#  {'imports': [], 'name': 'CS467'},
#  {'imports': ['CS111', 'TU110', 'CS102'], 'name': 'CS300'},
#  {'imports': [], 'name': 'SW478'},
#  {'imports': ['CS102', 'TU110'], 'name': 'SW213'},
#  {'imports': ['TU154', 'MA211'], 'name': 'MW314'},
#  {'imports': [], 'name': 'BA291'},
#  {'imports': ['MW313', 'TH161'], 'name': 'SW475'},
#  {'imports': ['CS295'], 'name': 'CS396'},
#  {'imports': [], 'name': 'CS427'},
#  {'imports': [], 'name': 'ES356'},
#  {'imports': [], 'name': 'CS387'},
#  {'imports': [], 'name': 'CS286'},
#  {'imports': [], 'name': 'CS297'},
#  {'imports': [], 'name': 'CS429'},
#  {'imports': [], 'name': 'CS446'},
#  {'imports': ['CS102', 'CS111'], 'name': 'SW335'},
#  {'imports': [], 'name': 'CS356'},
#  {'imports': ['CS105', 'MA211'], 'name': 'HR201'},
#  {'imports': ['SW335'], 'name': 'CS459'},
#  {'imports': ['TH161'], 'name': 'SO201'},
#  {'imports': ['SC185', 'SC173'], 'name': 'NS132'},
#  {'imports': ['TU120'], 'name': 'TA395'},
#  {'imports': [], 'name': 'CJ321'},
#  {'imports': [], 'name': 'CS397'},
#  {'imports': [], 'name': 'CS398'},
#  {'imports': ['CS395', 'CS341'], 'name': 'CS348'},
#  {'imports': ['SW111', 'MW313'], 'name': 'CJ317'},
#  {'imports': ['TH161'], 'name': 'MW313'},
#  {'imports': [], 'name': 'CJ316'},
#  {'imports': ['SC123', 'TU110'], 'name': 'MA216'},
#  {'imports': [], 'name': 'CS407'},
#  {'imports': ['CS102'], 'name': 'CS115'},
#  {'imports': [], 'name': 'CS457'},
#  {'imports': [], 'name': 'CS388'},
#  {'imports': [], 'name': 'CS426'},
#  {'imports': ['CS311', 'TU100'], 'name': 'CS449'},
#  {'imports': [], 'name': 'CS408'},
#  {'imports': [], 'name': 'CJ315'},
#  {'imports': ['CS101'], 'name': 'CS285'},
#  {'imports': ['CS398', 'CS314', 'CS311'], 'name': 'CS399'},
#  {'imports': [], 'name': 'PY218'},
#  {'imports': ['TU154', 'CS284'], 'name': 'CS328'},
#  {'imports': ['EL172'], 'name': 'AT366'},
#  {'imports': ['EG241'], 'name': 'CS359'},
#  {'imports': [], 'name': 'JC201'},
#  {'imports': [], 'name': 'TU153'},
#  {'imports': ['TU120', 'AT326'], 'name': 'ES456'},
#  {'imports': ['CJ315', 'CS341', 'MA211'], 'name': 'CS469'},
#  {'imports': ['CS301', 'ST216'], 'name': 'CS479'},
#  {'imports': ['MA212'], 'name': 'EC210'},
#  {'imports': ['CS284', 'CS223'], 'name': 'CS499'},
#  {'imports': ['SC173'], 'name': 'PY211'},
#  {'imports': ['EL295'], 'name': 'PE245'},
#  {'imports': ['TU120', 'MA211', 'CS395'], 'name': 'CS447'},
#  {'imports': ['CS102'], 'name': 'ES256'},
#  {'imports': ['CS111'], 'name': 'AS171'},
#  {'imports': ['CS385'], 'name': 'TU116'},
#  {'imports': ['CS101'], 'name': 'PM235'},
#  {'imports': ['MW314', 'CJ317'], 'name': 'CS496'},
#  {'imports': [], 'name': 'PM236'},
#  {'imports': ['TU110', 'EL171', 'CS251'], 'name': 'EG241'},
#  {'imports': ['CS213', 'TH161'], 'name': 'AT207'},
#  {'imports': [], 'name': 'SW366'},
#  {'imports': ['SW478', 'SW365', 'ST216'], 'name': 'MU100'},
#  {'imports': ['CS222'], 'name': 'PY237'},
#  {'imports': ['MA212'], 'name': 'JC200'},
#  {'imports': [], 'name': 'IS201'},
#  {'imports': ['EL295', 'CS101', 'SC173'], 'name': 'TU115'},
#  {'imports': ['CS284', 'TH161'], 'name': 'JP171'},
#  {'imports': ['CS214', 'CS486'], 'name': 'PY226'},
#  {'imports': ['EL171'], 'name': 'PY267'},
#  {'imports': [], 'name': 'MA217'},
#  {'imports': [], 'name': 'MU130'},
#  {'imports': [], 'name': 'JC260'},
#  {'imports': ['EL295', 'CS101', 'AT326'], 'name': 'FN211'},
#  {'imports': ['SW365', 'SC185'], 'name': 'MU135'},
#  {'imports': [], 'name': 'TD436'},
#  {'imports': [], 'name': 'PM215'},
#  {'imports': [], 'name': 'MU278'},
#  {'imports': ['CS101', 'CS214', 'SW111'], 'name': 'MU202'},
#  {'imports': [], 'name': 'RT326'},
#  {'imports': [], 'name': 'MA221'},
#  {'imports': [], 'name': 'PE240'},
#  {'imports': [], 'name': 'DM201'},
#  {'imports': [], 'name': 'CS275'},
#  {'imports': [], 'name': 'CF367'},
#  {'imports': [], 'name': 'CF366'},
#  {'imports': [], 'name': 'HS266'},
#  {'imports': [], 'name': 'HS269'},
#  {'imports': [], 'name': 'SW224'},
#  {'imports': [], 'name': 'PY217'},
#  {'imports': [], 'name': 'GE311'},
#  {'imports': [], 'name': 'SW223'},
#  {'imports': [], 'name': 'MW318'},
#  {'imports': [], 'name': 'GE225'},
#  {'imports': [], 'name': 'HS356'},
#  {'imports': [], 'name': 'AS178'},
#  {'imports': [], 'name': 'SW489'},
#  {'imports': [], 'name': 'SN212'},
#  {'imports': [], 'name': 'JP172'},
#  {'imports': [], 'name': 'SW222'},
#  {'imports': [], 'name': 'MU275'},
#  {'imports': [], 'name': 'AT346'},
#  {'imports': [], 'name': 'MU277'},
#  {'imports': [], 'name': 'ST218'},
#  {'imports': [], 'name': 'CS231'},
#  {'imports': [], 'name': 'RE333'},
#  {'imports': [], 'name': 'TU156'},
#  {'imports': [], 'name': 'AN201'},
#  {'imports': [], 'name': 'JC281'},
#  {'imports': [], 'name': 'SW467'},
#  {'imports': [], 'name': 'TU111'},
#  {'imports': [], 'name': 'AS177'},
#  {'imports': [], 'name': 'DM215'},
#  {'imports': [], 'name': 'PC286'},
#  {'imports': [], 'name': 'FD211'},
#  {'imports': [], 'name': 'EL202'},
#  {'imports': [], 'name': 'AT336'},
#  {'imports': [], 'name': 'NS112'},
#  {'imports': [], 'name': 'DM207'},
#  {'imports': [], 'name': 'CN342'},
#  {'imports': [], 'name': 'SW486'},
#  {'imports': [], 'name': 'SW214'},
#  {'imports': [], 'name': 'EL231'},
#  {'imports': [], 'name': 'HS360'}]

# %%
import json
with open('bundle_files/flare-imports.json','w') as fp:
    json.dump(data3, fp,indent=4, separators=(',', ': '))
