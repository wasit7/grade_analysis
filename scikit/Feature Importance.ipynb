# %%
pwd
# Out:
# u'C:\\Users\\Wasit\\Documents\\GitHub\\grade_analysis\\scikit'

# %%
import pandas as pd
import numpy as np
df_csv= pd.read_pickle("../df_noplus/df5.pkl")
all_subjects=df_csv['COURSEID'].value_counts()
##removing any subject enrolled less than 20 times
all_subjects=all_subjects[all_subjects[:]>=20]
print df_csv.shape
df_csv=df_csv[df_csv["COURSEID"].isin(all_subjects.index)]
print df_csv.shape
# Out:
# (28272, 199)
# (27994, 199)

# %%
pattern_names=df_csv.columns[4:]
for subject,count in all_subjects.iteritems():
    print subject
    ##load data
    dfx=df_csv[df_csv['COURSEID']==subject]
    dfx=dfx.iloc[np.random.permutation(len(dfx))]
    ##convert to np.array
    X=dfx.as_matrix( dfx.columns[4:] )
    y=dfx.as_matrix( ['GRADE'] ).T[0]
    ##evaluation
# Out:
# MA211
# CS102
# CS101
# TU154
# TH161
# CS111
# CS213
# EL171
# SC135
# PY228
# EL172
# SC185
# TU110
# CS223
# TU120
# ST216
# CS284
# EL295
# TU130
# MA212
# MA332
# CS314
# CS222
# CS214
# CS261
# CS251
# CS281
# CS341
# EL395
# CS301
# CS311
# CS374
# CS302
# CS401
# CS342
# CS105
# HO201
# CS395
# CS402
# CS365
# EL070
# AT326
# TU100
# CS289
# CS385
# AT316
# CS326
# TU122
# CS288
# CS487
# CS211
# CS489
# SC123
# SC173
# CS296
# CS488
# SW111
# CS367
# SW365
# CS486
# SW212
# CS409
# SW221
# CS215
# CS386
# CS366
# CS295
# CS377
# LA209
# CS456
# CS467
# CS300
# SW478
# SW213
# MW314
# BA291
# SW475
# CS396
# CS427
# ES356
# CS387
# CS286
# CS297
# CS429
# CS446
# SW335
# CS356
# HR201
# CS459
# SO201
# NS132
# TA395
# CJ321
# CS397
# CS398
# CS348
# CJ317
# MW313
# CJ316
# MA216
# CS407
# CS115
# CS457
# CS388
# CS426
# CS449
# CS408
# CJ315
# CS285
# CS399

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier

subject='MA211'
print subject

##load data
dfx=df_csv[df_csv['COURSEID']==subject]
dfx=dfx.iloc[np.random.permutation(len(dfx))]
##convert to np.array
X=dfx.as_matrix( dfx.columns[4:] )
y=dfx.as_matrix( ['GRADE'] ).T[0]

# Build a forest and compute the feature importances
forest = ExtraTreesClassifier(n_estimators=250,
                              random_state=0)

forest.fit(X, y)
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_],
             axis=0)
indices = np.argsort(importances)[::-1]
# Print the feature ranking
print("Feature ranking:")

for f in range(X.shape[1]):
    print("%d. subject %s (%f)" % (f + 1, pattern_names[indices[f]], importances[indices[f]]))
# Out:
# MA211
# Feature ranking:
# 1. subject TU154 (0.098677)
# 2. subject SC135 (0.091395)
# 3. subject EL171 (0.080204)
# 4. subject CS102 (0.079131)
# 5. subject TH161 (0.075852)
# 6. subject CS101 (0.066691)
# 7. subject SC185 (0.061306)
# 8. subject EL172 (0.042748)
# 9. subject CS105 (0.036772)
# 10. subject CS111 (0.035789)
# 11. subject TU120 (0.032448)
# 12. subject PY228 (0.028622)
# 13. subject MA211 (0.028249)
# 14. subject TU110 (0.023366)
# 15. subject EL070 (0.019502)
# 16. subject SC123 (0.013448)
# 17. subject TU130 (0.012499)
# 18. subject SW212 (0.011054)
# 19. subject TU100 (0.010509)
# 119. subject CS300 (0.000000)
# 120. subject CN342 (0.000000)
# 121. subject CS215 (0.000000)
# 122. subject AS178 (0.000000)
# 123. subject CS211 (0.000000)
# 124. subject CS285 (0.000000)
# 125. subject TU156 (0.000000)
# 126. subject CS407 (0.000000)
# 127. subject MU278 (0.000000)
# 128. subject PM235 (0.000000)
# 129. subject PM215 (0.000000)
# 130. subject PE245 (0.000000)
# 131. subject PE240 (0.000000)
# 132. subject PC286 (0.000000)
# 133. subject MW318 (0.000000)
# 134. subject MU277 (0.000000)
# 135. subject PY217 (0.000000)
# 136. subject MU202 (0.000000)
# 137. subject MU135 (0.000000)
# 138. subject MU130 (0.000000)
# 139. subject MU100 (0.000000)
# 140. subject MA221 (0.000000)
# 141. subject MA217 (0.000000)
# 142. subject PY211 (0.000000)
# 143. subject PY226 (0.000000)
# 144. subject CS408 (0.000000)
# 145. subject SW223 (0.000000)
# 146. subject TU111 (0.000000)
# 147. subject TD436 (0.000000)
# 148. subject SW489 (0.000000)
# 149. subject SW486 (0.000000)
# 150. subject SW467 (0.000000)
# 151. subject SW224 (0.000000)
# 152. subject SW222 (0.000000)
# 153. subject PY237 (0.000000)
# 154. subject SW214 (0.000000)
# 155. subject ST218 (0.000000)
# 156. subject SN212 (0.000000)
# 157. subject RT326 (0.000000)
# 158. subject RE333 (0.000000)
# 159. subject PY267 (0.000000)
# 160. subject JP172 (0.000000)
# 161. subject JP171 (0.000000)
# 162. subject JC281 (0.000000)
# 163. subject CS459 (0.000000)
# 164. subject DM215 (0.000000)
# 165. subject DM207 (0.000000)
# 166. subject CS499 (0.000000)
# 167. subject CS496 (0.000000)
# 168. subject CS479 (0.000000)
# 169. subject CS469 (0.000000)
# 170. subject CS457 (0.000000)
# 171. subject JC260 (0.000000)
# 172. subject CS456 (0.000000)
# 173. subject CS449 (0.000000)
# 174. subject CS447 (0.000000)
# 175. subject CS446 (0.000000)
# 176. subject CS427 (0.000000)
# 177. subject CS426 (0.000000)
# 178. subject EC210 (0.000000)
# 179. subject EG241 (0.000000)
# 180. subject EL202 (0.000000)
# 181. subject EL231 (0.000000)
# 182. subject ES256 (0.000000)
# 183. subject ES456 (0.000000)
# 184. subject FD211 (0.000000)
# 185. subject FN211 (0.000000)
# 186. subject GE311 (0.000000)
# 187. subject HR201 (0.000000)
# 188. subject HS266 (0.000000)
# 189. subject HS269 (0.000000)
# 190. subject HS356 (0.000000)
# 191. subject HS360 (0.000000)
# 192. subject IS201 (0.000000)
# 193. subject JC200 (0.000000)
# 194. subject JC201 (0.000000)
# 195. subject AN201 (0.000000)

# %%
 pattern_names[0]
# Out:
# 'AN201'

# %%
import json

# %%
data=[
{"name":"MA211","imports":["TU154","SC135","EL171","CS102","TH161"]},
{"name":"TU154","imports":[]},
{"name":"SC135","imports":[]},
{"name":"EL171","imports":[]},
{"name":"CS102","imports":[]},
{"name":"TH161","imports":[]},
]

with open('bundle_files/flare-imports.json','w') as fp:
    json.dump(data, fp)

# %%
with open('bundle_files/flare-imports.json','r') as fp:
    j=fp.read()
print j
# Out:
# [{"imports": ["TU154", "SC135", "EL171", "CS102", "TH161"], "name": "MA211"}, {"imports": [], "name": "TU154"}, {"imports": [], "name": "SC135"}, {"imports": [], "name": "EL171"}, {"imports": [], "name": "CS102"}, {"imports": [], "name": "TH161"}]
